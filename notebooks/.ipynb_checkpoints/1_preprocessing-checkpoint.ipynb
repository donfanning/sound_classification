# %%
import pandas as pd
import numpy as np
import librosa
import librosa.display
import matplotlib.pyplot as plt
import IPython.display as ipd
import os

# %% [markdown]
# ## file analysis

# %%
#total filecount
words = sum([len(files) for r, d, files in os.walk('../data/speech_commands_v0.01')])
words
# Out:
# 64729

# %%
#get a count of the word wave files by word category
filepath = '../data/speech_commands_v0.01/'
wav_dict = {}
for folder in os.listdir(filepath):
    count = 0
    if folder == ".DS_Store":
            continue
    if folder == 'validation_list.txt':
            continue
    if folder == 'LICENSE':     
            continue
    if folder == 'README.md':     
            continue
    if folder == 'testing_list.txt':
            continue
    for file in os.listdir(filepath +folder):
        if file.endswith('.wav'):
            count += 1          
    wav_dict[folder] = count
wav_dict
# Out:
# {'right': 2367,
#  'eight': 2352,
#  'cat': 1733,
#  'tree': 1733,
#  'bed': 1713,
#  'happy': 1742,
#  'go': 2372,
#  'dog': 1746,
#  'no': 2375,
#  'wow': 1745,
#  'nine': 2364,
#  'left': 2353,
#  'stop': 2380,
#  'three': 2356,
#  '_background_noise_': 6,
#  'sheila': 1734,
#  'one': 2370,
#  'bird': 1731,
#  'zero': 2376,
#  'seven': 2377,
#  'up': 2375,
#  'marvin': 1746,
#  'two': 2373,
#  'house': 1750,
#  'down': 2359,
#  'six': 2369,
#  'yes': 2377,
#  'on': 2367,
#  'five': 2357,
#  'off': 2357,
#  'four': 2372}

# %% [markdown]
# ## explore an audio file
# To begin I explore basic elements of an audio file to evaluate what may be good predictive features.

# %%
# Visualize via modeling array, this file is 'right'
right, sr_r = librosa.load('../data/rest/me_right.wav')
ipd.Audio(right, rate =sr)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
fig = plt.figure(figsize=(14, 8))
ax1 = fig.add_subplot(211)
ax1.set_title('Raw wave')
ax1.set_ylabel('Amplitude')
ax1.set_xlabel('Seconds')
ax1.plot(right);

# %%
#onvert to log scale, decibels, using peak power as reference
def spec(signal):
    R = librosa.feature.melspectrogram(signal)
    log_R = librosa.power_to_db(R, ref=np.max)
    plt.figure(figsize=(12, 4))
    librosa.display.specshow(log_R, x_axis='time', y_axis='mel')
    plt.title('Me saying' + signal)
    return plt.tight_layout()

# %%
spec(right)

# %%
#plot with onsets
hop_length = 512
# frame numbers of estimated onsets
onset_frames = librosa.onset.onset_detect(right, backtrack=True)
#onsets into units of seconds
onset_times = librosa.frames_to_time(onset_frames)
#onsets to units of samples
onset_samples = librosa.frames_to_samples(onset_frames)
#plot onssts on top of a specgram
X = librosa.stft(right)
Xdb = librosa.amplitude_to_db(abs(X), ref=np.max)

#logS = librosa.logamplitude(S)
plt.figure(figsize=(12, 4))
librosa.display.specshow(Xdb, x_axis='time', y_axis='log')
plt.vlines(onset_times, 0, 10000, color='w');

# %%
#load and pull out some feature arrays
def features(signal):
    y, sr = librosa.load(signal)   
    S = librosa.feature.melspectrogram(y, sr=sr, n_mels=128)
    log_S = librosa.power_to_db(S, ref=np.max
    mfcc = librosa.feature.mfcc(S=log_S, n_mfcc=24)
    mfcc_delta = librosa.feature.delta(mfcc)
    mfcc_delta2 = librosa.feature.delta(mfcc, order=2)
    #average of mfccs
    mfcc = np.mean(mfcc.T, axis = 0)
    #average of deltas
    mfcc_delta = np.mean(mfcc_delta.T, axis = 0)
    # average of delta deltas
    mfcc_delta2 = np.mean(mfcc_delta2.T, axis = 0)
    return mfcc, mfcc_delta, mfcc_delta2

# %%
#only mel spectogram
S1 = librosa.feature.melspectrogram(right, n_fft=4096)
logS1 = librosa.power_to_db(abs(S1))
plt.figure(figsize=(15, 5))
librosa.display.specshow(logS1, x_axis='time', y_axis='mel')
plt.colorbar(format='%+2.0f dB');

# %%
def mfcc(filepath, max_pad_len=11):
    wave, sr = librosa.load(filepath, mono=True, sr=None)
    wave = wave[::3]
    mfcc = librosa.feature.mfcc(wave, sr=16000)
    pad_width = max_pad_len - mfcc.shape[1]
    mfcc = np.pad(mfcc, pad_width=((0, 0), (0, pad_width)), mode='constant')
    return mfcc
#happy =mfcc('./speech_commands_v0.01/happy/211ccd2e_nohash_0.wav')

# %%
happy =mfcc('./speech_commands_v0.01/happy/146d97db_nohash_0.wav')
librosa.display.specshow(happy);
plt.colorbar();

# %% [markdown]
# ## visualize
# Loading in the chosen feature arrays from notebook 2

# %%
arrays = np.load('./mels/word_arrays.npy')
targets = np.load('./mels/word_targets.npy')

# %%
plt.imshow(arrays[0]);

# %%
#20 people saying 'one'
array_plot = []
for array, target in zip(arrays, targets):
    array_plot.append(array)
    if len(array_plot) == 20:
        print(target)
        break
x = np.concatenate(array_plot, axis=0)  
plt.figure(figsize = (20, 6))
plt.imshow(x.T, cmap ='inferno', aspect ='auto');
# Out:
# 0

# %%
array_plot = []
for array, target in zip(arrays, targets):
    if target == 30:
        array_plot.append(array)
        if len(array_plot) == 20:
            print(target)
            break

x = np.concatenate(array_plot, axis=0)  
plt.figure(figsize = (20, 6))
plt.imshow(x.T, cmap = 'bone', aspect ='auto');
# Out:
# 30
